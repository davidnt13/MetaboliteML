# %%
import pandas as pd

# %%
acetylNonNPC = 'Acetylcholinesterase_CHEMBL220_nonNP_coati_descriptors.csv'
monoNonNPC = 'Monoamine_oxidase_A_CHEMBL1951_nonNP_coati_descriptors.csv'
tyroNonNPC = 'Protein-tyrosine_phosphatase_1B_CHEMBL335_nonNP_coati_descriptors.csv'

acetylNPC = 'Acetylcholinesterase_CHEMBL220_NP_coati_descriptors.csv'
monoNPC = 'Monoamine_oxidase_A_CHEMBL1951_NP_coati_descriptors.csv'
tyroNPC = 'Protein-tyrosine_phosphatase_1B_CHEMBL335_NP_coati_descriptors.csv'

# %%
acetylNonNP = '../Met_Files/Acetylcholinesterase_CHEMBL220_nonNP.csv'
monoNonNP = '../Met_Files/Monoamine_oxidase_A_CHEMBL1951_nonNP.csv'
tyroNonNP = '../Met_Files/Protein-tyrosine_phosphatase_1B_CHEMBL335_nonNP.csv'

acetylNP = '../Met_Files/Acetylcholinesterase_CHEMBL220_NP.csv'
monoNP = '../Met_Files/Monoamine_oxidase_A_CHEMBL1951_NP.csv'
tyroNP = '../Met_Files/Protein-tyrosine_phosphatase_1B_CHEMBL335_NP.csv'

# %%
aNonNPC = pd.read_csv(acetylNonNPC)
mNonNPC = pd.read_csv(monoNonNPC)
tNonNPC = pd.read_csv(tyroNonNPC)

aNPC = pd.read_csv(acetylNPC)
mNPC = pd.read_csv(monoNPC)
tNPC = pd.read_csv(tyroNPC)

# %%
aNonNP = pd.read_csv(acetylNonNP)
mNonNP = pd.read_csv(monoNonNP)
tNonNP = pd.read_csv(tyroNonNP)

aNP = pd.read_csv(acetylNP)
mNP = pd.read_csv(monoNP)
tNP = pd.read_csv(tyroNP)

# %%
pd.concat([aNonNPC, aNonNP['pIC50']], axis = 1).to_csv('Acetylcholinesterase_CHEMBL220_nonNP_coati_descriptors2.csv')
pd.concat([mNonNPC, mNonNP['pIC50']], axis = 1).to_csv('Monoamine_oxidase_A_CHEMBL1951_nonNP_coati_descriptors2.csv')
pd.concat([tNonNPC, tNonNP['pIC50']], axis = 1).to_csv('Protein-tyrosine_phosphatase_1B_CHEMBL335_nonNP_coati_descriptors2.csv')

pd.concat([aNPC, aNonNP['pIC50']], axis = 1).to_csv('Acetylcholinesterase_CHEMBL220_NP_coati_descriptors2.csv')
pd.concat([mNPC, mNonNP['pIC50']], axis = 1).to_csv('Monoamine_oxidase_A_CHEMBL1951_NP_coati_descriptors2.csv')
pd.concat([tNPC, tNonNP['pIC50']], axis = 1).to_csv('Protein-tyrosine_phosphatase_1B_CHEMBL335_NP_coati_descriptors2.csv')
